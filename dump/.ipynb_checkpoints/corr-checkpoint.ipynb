# %%
import pandas as pd
import numpy as np
from sklearn.metrics import mean_absolute_error, mean_squared_error
import matplotlib.pyplot as plt

# %%
df = pd.read_excel("/home/satyukt/Projects/1000/soil_health/dump/Sample Data_Soil Test_2.xlsx")
rec = 1000
df_tmp = df.loc[:rec, :]

# %%
df_pred = pd.read_csv("newAlgo_first1000.csv").loc[:rec, :]

# %%
def plot(dff, y_test, i):
    m, b = np.polyfit(dff['y_test'] , dff['preds'],1 )
    plt.subplots(1,1)
    plt.scatter(dff['y_test'],dff['preds'])
    plt.title(i)
    plt.plot(y_test, m*y_test + b)
    plt.xlabel('Field')
    plt.ylabel('Predicted')


def cal_error(dff, y_test, predictions):
    mae = mean_absolute_error(y_test, predictions)
    rmse = mean_squared_error(y_test, predictions,squared=False)
    var_pred = predictions.var()
    corr = y_test.corr(predictions) 
    bias = (predictions - y_test).sum()/(y_test.size)
    # print(bias)
    return mae, rmse, var_pred, corr, bias

# %%
params = ['P', 'N', 'OC', 'K', 'pH']

bias_crr = [-13.122, -115.150, -0.38, 238.1393, 0.8017]
# fig, ax = fig
for i, j in zip(params, bias_crr):
    y_test = df_tmp.loc[:,i]

    preds = df_pred.loc[:, i]#.apply(lambda x: x - j)

    dff = pd.concat([y_test.reset_index(drop=True),pd.DataFrame(preds)],axis=1)
    dff.columns = ['y_test','preds']
    dff.dropna(inplace=True)
    mae, rmse, var_pred, corr, bias = cal_error(dff, dff.loc[:,"y_test"], dff.loc[:,"preds"])
    
    print(f"{i }:", "mae ->", mae, " rmse ->", rmse, " var_pred ->" ,var_pred, " corr ->", corr, "bias ->" , bias )
    plot(dff, dff['y_test'], i)
# Out:
# P: mae -> 5.421477892462976  rmse -> 6.7994137691161525  var_pred -> 20.463712378591463  corr -> 0.019150740923607336 bias -> -2.1633201236006387
# N: mae -> 89.0869209501341  rmse -> 103.3563877342818  var_pred -> 628.8836468795512  corr -> -0.044308687090066454 bias -> -87.47995195386812
# OC: mae -> 0.31157827866086807  rmse -> 0.35702922914588686  var_pred -> 0.022227569145004046  corr -> 0.0029243859571444013 bias -> -0.2899260747195673
# K: mae -> 24.609341084714057  rmse -> 30.847470642360385  var_pred -> 603.353459775135  corr -> -0.012078496686414045 bias -> -9.441948629234025
# pH: mae -> 0.5596745896631192  rmse -> 0.6396870078038343  var_pred -> 0.11810862732708204  corr -> 0.013415003745367625 bias -> 0.5325982946054469

# %%
# soil_cr = df.corr(method='pearson')




# dff, y_test, predictions= gen_predictions(model, target)
mae, rmse, var_pred, corr = cal_error(dff, y_test, predictions)

# sb.set(style="white")

# # Generate a mask for the upper triangle
# mask = np.zeros_like(soil_cr, dtype=np.bool)
# mask[np.triu_indices_from(mask)] = True

# # Set up the matplotlib figure
# f, ax = plt.subplots(figsize=(11, 9))

# # Generate a custom diverging colormap
# cmap = sb.diverging_palette(220, 10, as_cmap=True)

# # Draw the heatmap with the mask and correct aspect ratio
# sb.heatmap(soil_cr, mask=mask, cmap=cmap, vmax=.3, center=0, annot=True,
#             square=True, linewidths=.5, cbar_kws={"shrink": .5})
# display(correlation_data_frame.describe())


# #Scatter matrix depicting correlation of soil nutrients
# pd.plotting.scatter_matrix(
#     correlation_data_frame,
#     figsize  = [15, 15],
# #     marker   = ".",
# #     s        = 0.2,
# #     diagonal = "kde"
# )


    # plot(dff, y_test)

# %% [markdown]
# # Clean SampleData

# %%
import pandas as pd
df = pd.read_csv("SampleData_Soil_Test_clean.csv")

# %%
import datetime

d =datetime.datetime.strptime('2021-03-3T09:12:31.094Z','%Y-%m-%dT%H:%M:%S.%f%z')

# datetime.datetime.strftime()

# %%
df = df[~df.loc[:, 'Date'].str.contains("36T|35T|37T|-34T|-32T|-33T")]

# %%
df.loc[:, 'Date'] = df['Date'].apply(lambda x : datetime.datetime.strptime(x,'%Y-%m-%dT%H:%M:%S.%f%z').date())

# %%
df[["Date","Latitude","Longitude","pH","N","P","K","OC"]].to_csv("sample_data_soil_test_clean.csv", index=False)

# %%
df = pd.read_csv("sample_data_soil_test_clean.csv")
df.drop_duplicates(subset = ['Latitude', 'Longitude', 'Date']).to_csv("sample_data_soil_test_clean.csv")

# %% [markdown]
# # download and extract bands from GEE

# %%
import pandas as pd

df = pd.read_csv("/home/satyukt/Desktop/myfiles/npk_model/jagadeesh/sample_soil_health_points2021-03-01_2021-03-30.csv")

# %%
df.drop('system:index',axis=1)
df.columns
# Out:
# Index(['system:index', 'B1', 'B10', 'B11', 'B12', 'B2', 'B3', 'B4', 'B5', 'B6',
#        'B7', 'B8', 'B8A', 'B9', 'Date', 'K', 'Latitude', 'Longitude', 'N',
#        'NDVI', 'NDVI_G', 'NDWI', 'OC', 'P', 'QA10', 'QA20', 'QA60', 'SR_N',
#        'SR_n2', 'TBVI1', 'date', 'field_1', 'pH', '.geo'],
#       dtype='object')

# %%
pd.read_csv("../data/training/training.csv").B1.hist()

# %%
df.B1.hist()

# %%
df[['B8','B4','B5','B11','B9','B1','SR_n2','SR_N','TBVI1','NDWI','NDVI_G','P','N','OC','K','pH']]\
    #.to_csv("/home/satyukt/Downloads/soil_test_clean.csv", index = False)
# Out:
#          B8    B4    B5   B11    B9    B1     SR_n2      SR_N     TBVI1  \
# 0      2281  1453  1776  2530  1129  1646  1.823341  2.078061  0.593385
# 1      2337  1611  2394  2997  1129  1646  1.516548  1.844804  0.617647
# 2      2255  1597  1810  2663  1129  1646  1.716134  1.917151  0.568110
# 3      2255  1597  1810  2663  1129  1646  1.716134  1.917151  0.568110
# 4      2337  1611  2394  2997  1129  1646  1.516548  1.844804  0.617647
# ...     ...   ...   ...   ...   ...   ...       ...       ...       ...
# 23556  2232  1316  1519  2172   605  1650  1.632772  1.777548  0.511276
# 23557  2232  1316  1519  2172   605  1650  1.632772  1.777548  0.511276
# 23558  2232  1316  1519  2172   605  1650  1.632772  1.777548  0.511276
# 23559  2232  1316  1519  2172   605  1650  1.632772  1.777548  0.511276
# 23560  2232  1316  1519  2172   605  1650  1.632772  1.777548  0.511276
#
#            NDWI    NDVI_G      P       N    OC       K    pH
# 0     -0.291619  0.338095  18.90  209.44  0.40  272.82  6.90
# 1     -0.205260  0.279064  11.95  188.19  0.40  251.32  6.90
# 2     -0.263659  0.335020  24.96  203.79  0.40  258.42  7.00
# 3     -0.263659  0.335020  21.89  212.15  0.40  272.70  7.10
# 4     -0.205260  0.279064  13.48  184.41  0.40  273.42  6.81
# ...         ...       ...    ...     ...   ...     ...   ...
# 23556 -0.240345  0.307497  70.32  180.46  0.77  366.75  6.93
# 23557 -0.240345  0.307497   7.01     NaN  0.78  337.51  6.67
# 23558 -0.240345  0.307497  70.32     NaN  0.82     NaN  6.70
# 23559 -0.240345  0.307497  74.02     NaN  0.88  148.06  4.50
# 23560 -0.240345  0.307497  83.90  157.95  0.88  337.50  6.69
#
# [23561 rows x 16 columns]
